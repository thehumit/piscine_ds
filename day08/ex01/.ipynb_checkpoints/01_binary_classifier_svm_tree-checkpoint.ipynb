# %% [markdown]
# # Day 08. Exercise 01
# # Binary classifier. SVM. Decision tree

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression
import sklearn
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Preprocessing and logreg visualization

# %% [markdown]
# Read the file `am_pm.csv` to a dataframe from the previous exercise.

# %% [markdown]
# 1. Draw a plot where the x-axis is `am`, the y-axis is `pm`, dots are the days, color depends on the target.
# 2. Add the decision boundary of logistic regression to the plot.
# 3. Draw the same plot (with the boundary), but the color should depend this time on the predictions.
#
# Now it should be clear for you how the logistic regression works.

# %%
df = pd.read_csv("../ex00/am_pm.csv", index_col=0)

# %%
plt.rcParams["figure.figsize"] = (20,8)

# %%
model = LogisticRegression(random_state=21, fit_intercept=False)

model.fit(np.array(df[["am", "pm"]]), df["target"])
# Out:
# LogisticRegression(fit_intercept=False, random_state=21)

# %%
def plot_decision_boundary(X, pred_func):
    x_min, x_max = X[:, 0].min() - 5, X[:, 0].max() + 5
    y_min, y_max = X[:, 1].min() - 5, X[:, 1].max() + 5
    h = (x_max - x_min) / 100
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z == "working_day"

    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha = 0.5)
#     plt.scatter(X[:, 0], X[:, 1], cmap=plt.cm.Spectral)

# %%
# Plot the decision boundary
plot_decision_boundary(np.array(df[["am", "pm"]]), lambda x: model.predict(x))

sns.scatterplot(data = df, x = "am", y = "pm", hue = "target", s = 100, palette={"working_day":"b", "weekend":"r"})
plt.title("Logistic Regression")
model.intercept_
# Out:
# array([0.])

# %%
plot_decision_boundary(np.array(df[["am", "pm"]]), lambda x: model.predict(x))
sns.scatterplot(data = df, x = "am", y = "pm", hue = "predicted", s = 100, palette={"working_day":"b", "weekend":"r"})
plt.title("Logistic Regression")
print(sklearn.metrics.accuracy_score(df.target, model.predict(df[["am", "pm"]])))
# Out:
# 0.6285714285714286
# /Users/tquintan/Library/Python/3.7/lib/python/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %% [markdown]
# ## 2. Standardizing and logreg

# %% [markdown]
# Linear models can be sensitive to the scale of your variables. You make it easier for them to find the optimal solution when you scale your features.
#
# 1. Apply `StandardScaler` to `X` and train logistic regression again with the same parameters.
# 2. Calculate `accuracy` for the new model. Did it get better than a naive classifier with the most popular class?
# 3. Draw the plots that were described above but for the new model.

# %%
model = LogisticRegression(random_state=21, fit_intercept=False)

scaler = StandardScaler()

df_scaled = scaler.fit_transform(df[["am", "pm"]])

model.fit(df_scaled, df["predicted"])


plot_decision_boundary(np.array(df_scaled), lambda x: model.predict(x))

plt.title("Logistic Regression")

print(sklearn.metrics.accuracy_score(df["target"], model.predict(df_scaled)))

sns.scatterplot(x = df_scaled[:,0], y = df_scaled[:,1], hue = model.predict(df_scaled), s = 100, palette={"working_day":"b", "weekend":"r"})
# model.predict(df_scaled)
# Out:
# 0.6285714285714286
# /Users/tquintan/Library/Python/3.7/lib/python/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n0001rn8000f5_/T/ipykernel_60156/734157913.py in <module>
#      14 print(sklearn.metrics.accuracy_score(df["target"], model.predict(df_scaled)))
#      15
# ---> 16 sns.scatterplot(x = df_scaled[:,0], y = df_scaled[:,1], hue = model.predict(df_scaled), s = 100, palette={"working_day":"b", "weekend":"r"})
#      17 # model.predict(df_scaled)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
df_scaled[:,1]
# Out:
# array([-0.71990365, -0.07182203, -0.59225121, -0.51369586, -0.49405703,
#        -0.46459877, -0.41550168, -0.60207063, -0.01290552,  1.54838202,
#        -0.71990365, -0.72972307, -0.57261237, -0.34676575, -0.22893273,
#         0.7431897 ,  0.56644017, -0.48423761, -0.17001622, -0.73954249,
#        -0.36640459,  0.08528866,  0.1049275 ,  0.56644017,  1.05741109,
#         1.88224224,  1.2734383 ,  4.25854152, -0.73954249, -0.70026481,
#        -0.28784924, -0.71008423, -0.60207063, -0.5333347 , -0.2682104 ])

# %% [markdown]
# ## 3. SVM

# %% [markdown]
# 1. Apply `SVC` model to the scaled dataframe using parameters `probability=True`, `random_state=21`.
# 2. Calculate `accuracy`.
# 3. Try different kernels, find the best in terms of accuracy.
# 4. Draw both plots again with the decisions boundary to see how this algorithm works.

# %% [markdown]
# ## 4. Decision tree

# %% [markdown]
# 1. Apply `DecisionTreeClassifier` to the scaled dataframe using parameters `max_depth=4`, `random_state=42`.
# 2. Calculate accuracy.
# 3. Try different values of `max_depth`.
# 4. Draw both plots again with the decisions boundary to see how this algorithm works.
# 5. Using method `.plot_tree()` visualize the decision tree itself. It is another way of thinking about how the algorithm works.
# 6. How many leaves in the visualized tree label days as working days? Put your answer in the markdown cell in the end of the section.
